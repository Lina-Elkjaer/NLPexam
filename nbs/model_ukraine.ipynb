# %% [markdown]
# ## Loading data

# %%
import re
import pandas as pd

# Prepare data
path_pkl = os.path.join("data", "test_df.pkl")
data = pd.read_pickle(path_pkl) 

print(len(data))

data = data[data["language"] == "uk"]

print(len(data))

data = data[data["confidence"] > 0.9]

print(len(data))

# make text column lower case
data.document = data['document'].map(lambda document: document.lower() if isinstance(document,str) else document)

# make lists
dates = data.date.to_list()
docs = data.document.to_list()
subreddits = data.sub_reddit.to_list()
language = data.language.to_list()
type = data.type.to_list()
# Out:
# 421537
# 846
# 562

# %%
data
# Out:
#                                                  document sub_reddit  \
# 6       11-річна українська гімнастка катя дяченко заг...    ukraina
# 17      ізюм, харківська область (120 км від харкова)....    ukraina
# 23       український дайджест - огляд подій за 23 березня    ukraina
# 49      музична пауза від surface tension. "ми вас всі...    ukraina
# 51      у рашистських загарбників – розрив шаблону від...    ukraina
# ...                                                   ...        ...
# 449221  мої близькі подруги з родиною недалеко, два дн...    ukraina
# 449277  до нашого відділу майєна приїжджає небагато лю...    ukraina
# 449281                                    #слава україні!    ukraina
# 449335  оце мене й лякає, ще не висохла кров вбитих ро...    ukraina
# 449343  ти зовсім сліпий? які нормальні люди? 5-10% ві...    ukraina
#
#               date        type language  confidence
# 6       2022-03-23  submission       uk    0.994467
# 17      2022-03-23  submission       uk    0.987032
# 23      2022-03-23  submission       uk    0.993930
# 49      2022-03-23  submission       uk    0.939258
# 51      2022-03-23  submission       uk    0.997888
# ...            ...         ...      ...         ...
# 449221  2022-03-07     comment       uk    0.979403
# 449277  2022-03-07     comment       uk    0.959939
# 449281  2022-03-07     comment       uk    0.991116
# 449335  2022-03-07     comment       uk    0.983650
# 449343  2022-03-07     comment       uk    0.990559
#
# [562 rows x 6 columns]

# %% [markdown]
# ### Checking if it works

# %%
pd.DataFrame.head(data)

for i in data["document"]:
    print (i)
# Out:
# 11-річна українська гімнастка катя дяченко загинула внаслідок бомбардування маріуполя роzійськими фашистами
# ізюм, харківська область (120 км від харкова). очами місцевого юнака зі смартфоном
# український дайджест - огляд подій за 23 березня
# музична пауза від surface tension. "ми вас всіх уб'ємо".
# у рашистських загарбників – розрив шаблону від якості життя в україні
# в україні оголосили першу підозру російському військовому за зґвалтування – генпрокурорка венедіктова
# водіям легкових авто на період воєнного стану дозволено керувати вантажівками
# використання ворогом геоміток/enemy use of geotags
# маріуполь. немає москаля, а є лише сира земля!
# доброго ранку, україно! 648 годин опору, дякую україна. маленька амелія співає гімн україни в лодзі, польща
# арестович: про російську армію. [23.03.22]
# glory to ukraine - слава україні
# "лучше таракана нашего е*ите!" частина білоруських військових не буде воювати проти україни
# ми всі повинні зупинити росію. світ повинен зупинити війну. я вдячний кожному, хто діє на підтримку україни, на підтримку свободи. але війна триває. терор проти мирних людей триває. вже місяць! так довго! це розбиває серце мені, всім українцям і кожній вільній людині на землі. тому я прошу вас висту
# інформація для людей, які тікають від війни в україні - information for people fleeing the war in ukraine [official info from the eu commission, also available in russian and english]
# український дайджест - огляд подій за 23 березня
# проросійська машина зламалася: шанси в опзж та інші
#   демо захищати свою землю,
#    будемо боротися з тобою до кінця.
#    не здамося, поки не виграємо війну.
#
#   що ви залишитесь, російські солдати, якщо ви залишитесь,
#    ніколи не підкориш україну.
#   києві є людина, яка змусила всіх нас повірити.
#   ж візьміть підказку і залиште нас у спокої сука.
#
#   іть додому російські солдати, йдіть додому.
#   вас немає власних додому блять?
#   демо захищати свою землю,
#    будемо боротися з тобою до кінця.
#    не здамося, поки не виграємо війну.
#
#    не росіяни. ми українці і ми вільні,
#   ми ніколи не просили бути вашими ворогами.
#    знищимо ваші танки та літаки. слава україні! героям слава, наша гордість.
#
#   іть додому російські солдати, йдіть додому.
#   вас немає власних додому блять?
#   демо захищати свою землю,
#    будемо боротися з тобою до кінця.
#    не здамося, поки не виграємо війну.
#    будемо битися з тобою на полях і на вулицях, доки твоя хуйло армія не відступить. путін іди на хуй! ми будемо стріляти в тебе в сраку.
#    будемо боротися за те, щоб україна знову стала вільною.
#
#   іть додому російські солдати, йдіть додому.
#   вас немає власних додому блять?
#   демо захищати наші домівки,
#    будемо боротися з тобою до кінця.
# ми не здамося, поки не виграємо війну.
#
# mostly google translate and eliminating the way-off translations i could identify. swear-words are total approximations.
# що це був за висєр зараз? ору на все село
# скільки платять? кілограм цукру за 10 ватних коментарів?
# "...гей, чувак, росіянин знаходиться в кущах на північ від тієї дороги. ви намалюйте на них вогонь, а моя група застрелить їх за тими руїнами..."
#
# cod player : "(shout) get in the choopaa!!"
#
# respawn in 5, 4, ...
# слава україні! 🇺🇦
# slava ukraini! heroyam slava!
#
# слава україні ! героям слава !
#
# glory to ukraine! glory to the heroes!
# slava ukraini! heroyam slava!
#
# слава україні ! героям слава !
#
# glory to ukraine! glory to the heroes!
# вбийте всіх цих російських лоханів!
# привітайся з моїм маленьким другом!
# "say hello to my little friend!"
# успіху вам! на скільки можемо, ми в міжнародної грамаді вас підтриматимемо!
# вічна пам'ять
#
# i hate this so much
# професійна шкідливість.
# слава україні.  героям слава.  смерть її ворогам.  любов, повага, шана і молитви від сша.  хай бог береже святу україну.
# forgot "in ukrainian"
#
# підручники для початкової школи українською мовою.
#
# it's very accurate.
# добре. так, воля працює. хоча сам я давно забув про тб, але декому похилому може й треба проривати інформаційний вакуум. у нас сусідка дуже похила тільки радіо слухає, наприклад.
# у сусідки по під'їзду тб теж працює, в неї "воля"
# тримайтесь. у знайомих на салт. шоссе, центрі та одеській інтернет працює.
#
# hold on. my acquaintances at saltiv ave, center and odeskaya disctict have working internet.
# дякую тобі! бо цей наратив вже заїбав, вони виставляють себе жертвами, поки наші рідні можуть померти, а у деяких вже померли! це просто верх егоїзму і терпілоїдності!
# слава австралії, слава україні
# угу, "спеціальна операція", "за два дні київ візьмемо", "одна нога тут - інша там", казали вони...
# слава україні
# кончені
# міжнародне свято на території снг?
# стаття 5 статуту нато: нато ніколи не вступає в конфлікти на стороні країни, яка не є членом альянсу.
# кім пизже)
# я знаю цю статтю. як вона перечить моїй позиції?
# стаття 5 статуту нато. приємного вивчення.
#
# але на майбутнє запам'ятай: ти -- кацап, а «русскій» -- це взагалі прикметник, прілагатєльноє по-вашому. ти ж, довбойоб, не кажеш на німця «німецький» чи на француза «французький».
# не вивчили ще кличний відмінок. ну і так гаразд.
# де теж саме? як ставляться люди до голодомору в росії і в україні?
# та хватить вже взивати до москалів,що вони повині це бачити. їм похуй або вони ще навпаки будуть радіти цьому
# тоді це було дуже важко тому, що країна ще десятками років знаходилась в окупації червоної чуми. постійна пропаганда, переписування історії, переслідування. лиш із падінням цього проклятого режиму почався повільний процес.
# наш обов'язок, не дати усім наступним поколінням забути це. обов'язок кожного батька, матері, бабусі, дідуся, сестри і брата.
# good work boys!!! слава україні!!!!
# слава вільній україні!
# не тобі, кацапу, мені пояснювати хто у нас і що захищає. наше населення, це українці які можуть мати будь яке походження. а твої "рускіє" це нелюдь яка всю свою жалюгідну історію не створила нічого корисного для цивілізації, ви тільки красти, брехати і вбивати беззахистних здатні. пішов нахуй, рускій карабль. зрозуміло? сумніваюсь. була б у тебе хоч капля розуму, ти б сюди не потикався зі своїм меканням.
# [ковбаса з написом «слава україні! русский военный корабль иди нах*й»](
#
# &gt;  "хочемо нашим людям дати трохи усмішки, надії та підтримати нашу армію. так вирішила вся наша команда однодумців", — повідомив менеджер зі збуту м'ясокомбінату ілля гусейнов.
#
# &gt;  ковбасу випускатимуть до перемоги україни у війні з росією.
# суперові наші діти!💪👍🇺🇦
# це прекрасно :) сподіваюсь після перемоги, буде час і можливість перейменовувати як місто так і область
# зробіть пост англійською.
# молодці)
# дискутувати з ботами не треба. я просто копі-пастю оцю заготовку:
#
# watch:
#
# read:
#
# educate yourself.
#
# раджу і вам так робити. це не для ботів, це для наівних людей які бачать вкиди ботів.
# дискутувати не треба. я просто копі-пастю оцю заготовку:
#
# watch:
#
# read:
#
# educate yourself.
#
# раджу і вам так робити. це не для ботів, це для наівних людей які бачать вкиди ботів.
# дискутувати не треба. я просто копі-пастю оцю заготовку:
#
# watch:
#
# read:
#
# educate yourself.
#
# раджу і вам так робити. це не для ботів, це для наівних людей які бачать вкиди ботів.
# запостіть це на англійській, з посиланням на оригінал від рнбо. американці теж дуже триггеряться на слово "nazi" та і з європи багато хто читае англомовні сабреддити.
# з метою дискредитації сил оборони україни ворог знімає та поширює постановочні відео з нелюдським ставленням нібито «українських військових» до «російських полонених».
# наголошую, військовослужбовці збройних сил україни та інших законних військових формувань неухильно дотримуються норм міжнародного гуманітарного права.
# закликаю враховувати реалії інформаційно-психологічної війни і довіряти лише офіційним джерелам.
#
# the enemy produces and shares videos with the inhuman treatment of alleged "russian prisoners" by "ukrainian soldiers" in order to discredit ukrainian defence forces.
# i emphasize that service members of the armed forces of ukraine and other legitimate military formations strictly adhere to the norms of international humanitarian law.
# i urge to take into account the realities of informational and psychological warfare and trust only official sources.
#
# here for y'all.
# ми виграємо це.
# проклятий путін
# again, nobody gives a fuck about your nazi viewpoints! птн хло. орки ідіть нахуй
# бідна собачка
# вони ще хочуть бойка в прем'єри і визнання динирилинири та крима росіянським
# українці. заходимо в телеграм сюди  і пишемо все що завгодно. це російмький чат.
# андрій хливнюк (бумбокс) ❤️
# боже як же душевно і гарно вміє цей воїн, низький уклін
# ну точність низка але квадрат обстрілєю рсзо дуже непогано
# героям слава. тримайтеся. я не втрачаю надії, що вони живі.
# все це чув тільки від арестовича, найвеличнішого військового стратега сучасності
#    всім всім, чим можемо
#
# будь ласка, якщо ви можете внести мінімальну суму, зараз ми маємо лише цю платформу, тому що ми перебуваємо в збройному конфлікті, і я не маємо часу відкривати рахунки чи розширювати інформацію в інших змі
# "рабів до раю не пускають"
# мої близькі подруги з родиною недалеко, два дні ре можу зв’язатись взагалі, до того, один з телефонів ще заряджали від машини. вода також не було, але я хоч могла почути раз на день, що вони живі. справді страшно, і не маєш змоги допомогти, але залишається лише вірити в краще та сили зсу.
# слава україні💛💙
#    нашого відділу майєна приїжджає небагато людей з україни
#
#   м потрібні ліки і їжа
#
# якщо ви можете допомогти нам розповсюдити інформацію, дуже дякуємо
#
# [
# #слава україні!
# оце мене й лякає, ще не висохла кров вбитих росіянами дітей, а люди тут вже починають їх відмазувати "не все они плахие".  ну як можно бути такими безхребетними і тупими.
#
# п.с. про мову не треба, це особистий вибір кожного, головне людиною бути, а  то я вже надивився на україномовних їбланів, які свого часу голосували за яника, і дибілів після 2014-го в стилі "в росії такі ж люди як і ми, то просто порошенко хоче війну щоб наживатися". мова не показник, від слова "взагалі"
# ти зовсім сліпий? які нормальні люди? 5-10% від населення? це маргінали, більшість звичайнісінькі фашисти. не треба тут самодурством займатись с приводу мільйонів тільки дивлячись на свого друга.
# ти що не бачиш, що між твоїм другом і середнім росіянином просто ментальна прірва?

# %%
print(dates[-1])
print(docs[-1])
# Out:
# 2022-03-07
# ти зовсім сліпий? які нормальні люди? 5-10% від населення? це маргінали, більшість звичайнісінькі фашисти. не треба тут самодурством займатись с приводу мільйонів тільки дивлячись на свого друга.
# ти що не бачиш, що між твоїм другом і середнім росіянином просто ментальна прірва?

# %%
#If this outputs anything, there is a problem. Something that should be a string is not...
for i in docs: 
    test = isinstance(i, str)
    if test == False: 
        print (test)

# %% [markdown]
# ## Training embeddings

# %%
import random
random.seed(29)

#Husk at installe sentence_transformers via terminalen
from sentence_transformers import SentenceTransformer

# Prepare embeddings
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = sentence_model.encode(docs, show_progress_bar=False)

# %% [markdown]
# ## Fitting the model

# %%
#Kør kun hvis chunken nedenfor ikke virker
from umap import UMAP
umap_model = UMAP(n_components=5, n_neighbors=15, min_dist=0.0, metric='cosine', random_state = 29)

# %%
#Skal virke for at få GPU'en til at køre hurtigere, men der er problemer med at loade cuml pakken

#from cuml.manifold import UMAP
#from cuml.cluster import HDBSCAN

# Create instances of GPU-accelerated UMAP and HDBSCAN
#umap_model = UMAP(n_components=5, n_neighbors=15, min_dist=0.0, metric='cosine', random_state = 29)
#hdbscan_model = HDBSCAN(min_samples=10, gen_min_span_tree=True)

# %%
from bertopic import BERTopic

#Kør hvis GPU opsætning IKKE virker
topic_model = BERTopic(language = "multilingual", verbose = True, calculate_probabilities = False, umap_model=umap_model)
#Kør hvis GPU opsætning virker
#topic_model = BERTopic(language = "multilingual", verbose = True, calculate_probabilities = False, umap_model=umap_model, hdbscan_model=hdbscan_model)


topics, probs = topic_model.fit_transform(docs, embeddings)
# Out:
# 2022-12-16 12:54:26,717 - BERTopic - Reduced dimensionality
# 2022-12-16 12:54:26,738 - BERTopic - Clustered reduced embeddings

# %% [markdown]
# ### Removing stopwords

# %%
topic_model.get_topic_info()[0:11]
# Out:
#    Topic  Count                   Name
# 0      0    475  0_не_слава_україні_на
# 1      1     87          1_не_на_що_це

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words="english")
#vectorizer_model = CountVectorizer(stop_words="english")

topic_model.update_topics(docs, vectorizer_model=vectorizer_model)

# %% [markdown]
# ### Investigating the model

# %%
topic_model.get_topic_info()[0:11]
# Out:
#    Topic  Count                   Name
# 0      0    475  0_не_слава_на_україні
# 1      1     87          1_не_на_що_це

# %% [markdown]
# ### Saving and loading models

# %%
#topic_model.save("models/model_medium")

# %%
#from bertopic import BERTopic

#topic_model = BERTopic.load("models/model_medium")

# %% [markdown]
# ## Visualizations

# %%
#Tager lang tid at køre, når vi har så mange små topics
#topic_model.visualize_topics()

# %% [markdown]
# ### Topics over time

# %% [markdown]
# ### Function for visualizing topics over time

# %%
import pandas as pd
from typing import List
import plotly.graph_objects as go
from sklearn.preprocessing import normalize


def visualize_topics_over_time(topic_model,
                               topics_over_time: pd.DataFrame,
                               top_n_topics: int = None,
                               topics: List[int] = None,
                               normalize_frequency: bool = False,
                               custom_labels: bool = False,
                               width: int = 1250,
                               height: int = 450) -> go.Figure:
    """ Visualize topics over time
    Arguments:
        topic_model: A fitted BERTopic instance.
        topics_over_time: The topics you would like to be visualized with the
                          corresponding topic representation
        top_n_topics: To visualize the most frequent topics instead of all
        topics: Select which topics you would like to be visualized
        normalize_frequency: Whether to normalize each topic's frequency individually
        custom_labels: Whether to use custom topic labels that were defined using 
                       `topic_model.set_topic_labels`.
        width: The width of the figure.
        height: The height of the figure.
    Returns:
        A plotly.graph_objects.Figure including all traces
    Examples:
    To visualize the topics over time, simply run:
    ```python
    topics_over_time = topic_model.topics_over_time(docs, timestamps)
    topic_model.visualize_topics_over_time(topics_over_time)
    ```
    Or if you want to save the resulting figure:
    ```python
    fig = topic_model.visualize_topics_over_time(topics_over_time)
    fig.write_html("path/to/file.html")
    ```
    <iframe src="../../getting_started/visualization/trump.html"
    style="width:1000px; height: 680px; border: 0px;""></iframe>
    """
    colors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#ffffff', '#000000']

    # Select topics based on top_n and topics args
    freq_df = topic_model.get_topic_freq()
    freq_df = freq_df.loc[freq_df.Topic != -1, :]
    if topics is not None:
        selected_topics = list(topics)
    elif top_n_topics is not None:
        selected_topics = sorted(freq_df.Topic.to_list()[:top_n_topics])
    else:
        selected_topics = sorted(freq_df.Topic.to_list())

    # Prepare data
    if topic_model.custom_labels_ is not None and custom_labels:
        topic_names = {key: topic_model.custom_labels_[key + topic_model._outliers] for key, _ in topic_model.topic_labels_.items()}
    else:
        topic_names = {key: value[:40] + "..." if len(value) > 40 else value
                       for key, value in topic_model.topic_labels_.items()}
    topics_over_time["Name"] = topics_over_time.Topic.map(topic_names)
    data = topics_over_time.loc[topics_over_time.Topic.isin(selected_topics), :].sort_values(["Topic", "Timestamp"])

    # Add traces
    fig = go.Figure()
    for index, topic in enumerate(data.Topic.unique()):
        trace_data = data.loc[data.Topic == topic, :]
        topic_name = trace_data.Name.values[0]
        words = trace_data.Words.values
        if normalize_frequency:
            y = normalize(trace_data.Frequency.values.reshape(1, -1))[0]
        else:
            y = trace_data.Frequency
        fig.add_trace(go.Scatter(x=trace_data.Timestamp, y=y,
                                 mode='lines',
                                 marker_color=colors[index % 20],
                                 hoverinfo="text",
                                 name=topic_name,
                                 hovertext=[f'<b>Topic {topic}</b><br>Words: {word}' for word in words]))

    # Styling of the visualization
    fig.update_xaxes(showgrid=True)
    fig.update_yaxes(showgrid=True)
    fig.update_layout(
        yaxis_title="Normalized Frequency" if normalize_frequency else "Frequency",
        title={
            'text': "<b>Topics over Time",
            'y': .95,
            'x': 0.40,
            'xanchor': 'center',
            'yanchor': 'top',
            'font': dict(
                size=22,
                color="Black")
        },
        template="simple_white",
        width=width,
        height=height,
        hoverlabel=dict(
            bgcolor="white",
            font_size=16,
            font_family="Rockwell"
        ),
        legend=dict(
            title="<b>Global Topic Representation",
        )
    )
    return fig

# %%
# Topics over time
topics_over_time = topic_model.topics_over_time(docs, dates, nr_bins=20)
#topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=20)

visualize_topics_over_time(topic_model, topics_over_time, top_n_topics=20)




# Visualize topics over time with the updated colors
#visualize_topics_over_time(model, topics_over_time)
# Out:
# 5it [00:00, 21.54it/s]
# <div>                            <div id="d9ada33c-b577-4b7b-8383-7e77a3740d2b" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9ada33c-b577-4b7b-8383-7e77a3740d2b")) {                    Plotly.newPlot(                        "d9ada33c-b577-4b7b-8383-7e77a3740d2b",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u0446\u0435, \u0449\u043e, \u043d\u0435, \u043d\u0430, \u0443\u043a\u0440\u0430\u0457\u043d\u0456","<b>Topic 0</b><br>Words: \u043d\u0435, \u0441\u043b\u0430\u0432\u0430, \u043d\u0430, \u0443\u043a\u0440\u0430\u0457\u043d\u0456, \u0449\u043e","<b>Topic 0</b><br>Words: \u043d\u0435, \u0441\u043b\u0430\u0432\u0430, \u043d\u0430, \u0449\u043e, \u0443\u043a\u0440\u0430\u0457\u043d\u0456","<b>Topic 0</b><br>Words: \u043d\u0435, \u0441\u043b\u0430\u0432\u0430, \u0443\u043a\u0440\u0430\u0457\u043d\u0456, \u0446\u0435, \u043d\u0430","<b>Topic 0</b><br>Words: \u043d\u0435, \u043d\u0430, \u0446\u0435, \u0443\u043a\u0440\u0430\u0457\u043d\u0456, \u0441\u043b\u0430\u0432\u0430"],"marker":{"color":"#e6194b"},"mode":"lines","name":"0_\u043d\u0435_\u0441\u043b\u0430\u0432\u0430_\u043d\u0430_\u0443\u043a\u0440\u0430\u0457\u043d\u0456","x":["2022-03-06T23:31:12","2022-03-08T00:00:00","2022-03-20T00:00:00","2022-03-22T00:00:00","2022-03-26T00:00:00"],"y":[40,159,86,95,95],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: \u043d\u0435, \u0442\u0430, \u043d\u0430, \u0449\u043e\u0431, \u0449\u043e","<b>Topic 1</b><br>Words: \u043d\u0435, \u0449\u043e, \u043d\u0430, \u0446\u0435, \u043c\u0438","<b>Topic 1</b><br>Words: \u043d\u0435, \u043d\u0430, \u043c\u0438, \u0449\u043e, \u0434\u043e","<b>Topic 1</b><br>Words: \u043d\u0435, \u0446\u0435, \u043d\u0430, \u0449\u043e, \u0442\u0430","<b>Topic 1</b><br>Words: \u043d\u0435, \u043d\u0430, \u0446\u0435, \u0442\u0430, \u0434\u043e"],"marker":{"color":"#3cb44b"},"mode":"lines","name":"1_\u043d\u0435_\u043d\u0430_\u0449\u043e_\u0446\u0435","x":["2022-03-06T23:31:12","2022-03-08T00:00:00","2022-03-20T00:00:00","2022-03-22T00:00:00","2022-03-26T00:00:00"],"y":[9,20,17,19,22],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.777 ...

# %% [markdown]
# ## Topics pr class

# %%
# Topics per class
#topics_per_class = topic_model.topics_per_class(docs, classes = subreddits)

language = data.language.to_list()
type = data.type.to_list()

topics_per_class = topic_model.topics_per_class(docs, classes = language)
# Out:
# 1it [00:00, 20.68it/s]

# %%
topic_model.visualize_topics_per_class(topics_per_class, top_n_topics=10)
# Out:
# <div>                            <div id="f20e4e50-2406-4ab4-8585-2384928fa248" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f20e4e50-2406-4ab4-8585-2384928fa248")) {                    Plotly.newPlot(                        "f20e4e50-2406-4ab4-8585-2384928fa248",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u043d\u0435, \u0441\u043b\u0430\u0432\u0430, \u043d\u0430, \u0443\u043a\u0440\u0430\u0457\u043d\u0456, \u0449\u043e"],"marker":{"color":"#E69F00"},"name":"0_\u043d\u0435_\u0441\u043b\u0430\u0432\u0430_\u043d\u0430_\u0443\u043a\u0440\u0430\u0457\u043d\u0456","orientation":"h","visible":true,"x":[475],"y":["uk"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: \u043d\u0435, \u043d\u0430, \u0449\u043e, \u0446\u0435, \u0442\u0430"],"marker":{"color":"#56B4E9"},"name":"1_\u043d\u0435_\u043d\u0430_\u0449\u043e_\u0446\u0435","orientation":"h","visible":"legendonly","x":[87],"y":["uk"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444 ...
